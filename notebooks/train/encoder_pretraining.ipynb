# %% [markdown]
# # ACNet - encoder pretraining

# %% [markdown]
# The encoders in the accompanying thesis publication are trained according to the

# %% [markdown]
# ## Setup

# %%
import os.path

try:
    from google.colab import drive
    drive.mount('/content/drive')
    _home = 'drive/MyDrive/tlacamr'
except ImportError:
    _home = '~'
finally:
    project_root = os.path.join(_home, 'tlacamr')

print(project_root)
# %cd $project_root
# Out:
# Mounted at /content/drive
# drive/MyDrive/tlacamr/tlacamr
# /content/drive/MyDrive/tlacamr/tlacamr

# %%
# %%capture
# !pip install .
### install statement should look like this once repo is public
###!pip install git+https://github.com/my-user/my-repo

# %%
## optional wandb login
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# ## MLP pretraining

# %% [markdown]
# ### Classification

# %%
#2048 to 256 Half-step regression encoder from ACNet mixed, no pairwise abstraction,
#all single randoms
# %%capture
# !python3 src/train.py +experiment/representation_learning/classification=single

# %% [markdown]
# ### Reconstruction

# %%
# 2048 to 256 Half-step Autoencoder from ACNet mixed, no pairwise abstraction, all single
#randoms 2048 to 256 Half-step regression encoder from ACNet mixed
# %%capture
# !python3 src/train.py +experiment/representation_learning/reconstruction=single_AE

# %% [markdown]
# ## AC pretraining

# %% [markdown]
# ## Joint

# %% [markdown]
# ### Classification

# %%
# 2048 to 256 Half-step Autoencoder from ACNet mixed, no pairwise abstraction, all single
#randoms 2048 to 256 Half-step regression encoder from ACNet mixed
# %%capture
# !python3 src/train.py +experiment/representation_learning/classification=joint

# %% [markdown]
# ### Reconstruction

# %%
# %%capture
# !python3 src/train.py +experiment/representation_learning/reconstruction=joint_AE

# %% [markdown]
# ## Siamese

# %% [markdown]
# ### Classification

# %% [markdown]
# #### Siamese classification - Manhattan distance

# %%
# %%capture
# !python3 src/train.py +experiment/representation_learning/classification=siamese_manhattan

# %% [markdown]
# #### Siamese classification - Hadamard product

# %%
# %%capture
# !python3 src/train.py +experiment/representation_learning/classification=siamese_hadamard

# %% [markdown]
# #### Siamese classification - Euclidean distance

# %%
# %%capture
# !python3 src/train.py +experiment/representation_learning/classification=siamese_euclidean

# %% [markdown]
# #### Siamese classification - Cosine similarity

# %%
# %%capture
# !python3 src/train.py +experiment/representation_learning/classification=siamese_cosine

# %% [markdown]
# #### Siamese autoencoder - Naive two pass BCE, symmetric loss

# %%
# %%capture
# !python3 src/train.py +experiment/representation_learning/reconstruction=siamese_AE

# %% [markdown]
# ### Semi Supervision

# %% [markdown]
# #### Siamese autoencoderSiamACLoss

# %%
# %%capture
# !python3 src/train.py +experiment/representation_learning/semi_supervision=siamese_AE_siamac

# %% [markdown]
# #### Siamese autoencoder SiamACLoss all positives

# %%
# %%capture
# !python3 src/train.py +experiment/representation_learning/semi_supervision=siamese_AE_siamac_positives

# %% [markdown]
# ### Self Supervision

# %% [markdown]
# #### Siamese autoencoder - Negative cosine similarity
#
# ---

# %%
# %%capture
# !python3 src/train.py +experiment/representation_learning/self_supervision=siamese_AE_ncs

# %% [markdown]
# #### Siamese autoencoder - NCS all positives

# %%
# %%capture
# !python3 src/train.py +experiment/representation_learning/self_supervision=siamese_AE_ncs_positives ++data.filter_type=positive

# %% [markdown]
# ### SimSiam

# %%
# %%capture
# !python3 src/train.py +experiment/representation_learning/self_supervision=simsiam_ncs

# %% [markdown]
# ### Simsiam - all positives

# %%
# %%capture
# !python3 src/train.py +experiment/representation_learning/self_supervision=simsiam_ncs_positives

# %% [markdown]
# ## Kill box, run after pretraining to save colab resources

# %%
from google.colab import runtime
runtime.unassign()
